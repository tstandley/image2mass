# %% [markdown]
# <a href="https://colab.research.google.com/github/Dene33/image2mass/blob/master/image2mass_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Initial imports and installations
# ###Follow the running process to press `Enter` and pass the `Google authentication ` where it's needed

# %%
# !add-apt-repository ppa:deadsnakes/ppa
# !apt-get update
# !apt-get install python3.5
# !apt-get install python3.5-dev

# !wget https://bootstrap.pypa.io/get-pip.py && python3.5 get-pip.py
  
# !pip3.5 install Pillow
# !pip3.5 install keras==2.1.1 # the most recent version (2.1.2 at time of writing) throws an error loading the model
# !pip3.5 install lz4
# !pip3.5 install opencv-python # or install opencv another way (this method doesn't support cv.imshow() or FFmpeg) but is much easier to install
# !pip3.5 install h5py
# !pip3.5 install tensorflow
# !pip3.5 install lz4
# !pip3.5 install numba

# !git clone https://github.com/Dene33/image2mass.git

import sys

print (sys.path)

sys.path[2] = '/usr/lib/python35.zip'
sys.path[3] = '/usr/lib/python3.5'
sys.path[4] = '/usr/lib/python3.5/lib-dynload'
sys.path[5] = '/usr/local/lib/python3.5/dist-packages'
sys.path[7] ='/usr/local/lib/python3.5/dist-packages/IPython/extensions'
print (sys.path)  

import os
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip3.5 install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

image2mass_models = ['1dZjcr7M-kp31z9UWKvX1F0M81jDHmmbF',
                     '1f8lAlhwLoTVU7P523R-ulT9pIivV2vxH',
                     '1bwot_XNtF-b9s0hd-MnMIn-VKtWAhqRO',
                     '1c7Wq1J9RrZ5HDyn1OrZeQVQ5lVE9CJVr']

image2mass_pklzs = ['1R1j7Srb9kztI2MZeDktbRvZEBPRwFwYt',
                    '1zYimskF-wAWeVOWyJjoH2S_pGkBwWnXS',
                    '1yGAAlzznmJdWU3U32EtIB-ggetzl9CL2',
                    '1_d-BsDeBsWYTbZTLvYXFIIlV3d75-JZc',
                    '101VbwOy_R3t9b8tI-Bhr-Awew3Vh_EX7',
                    '1d778NdVFV0b_xYY_ix-ylLXQfNZLsG3x',
                    '1X3hPBz6VO3kUjz2N7myzzO67KL0_TdXO']

# !mkdir image2mass/pklzs

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz

for file_id in image2mass_models:
  downloaded = drive.CreateFile({'id': file_id})
  print('Downloaded content "{}"'.format(downloaded.GetContentFile(downloaded['title'])))
  os.rename(downloaded['title'], 'image2mass/models/'+downloaded['title'])
  
for file_id in image2mass_pklzs:
  downloaded = drive.CreateFile({'id': file_id})
  print('Downloaded content "{}"'.format(downloaded.GetContentFile(downloaded['title'])))
  os.rename(downloaded['title'], 'image2mass/pklzs/'+downloaded['title'])
  
os.chdir('image2mass')
# Out:
#  This PPA contains more recent Python versions packaged for Ubuntu.
#
# Disclaimer: there's no guarantee of timely updates in case of security problems or other issues. If you want to use them in a security-or-otherwise-critical environment (say, on a production server), you do so at your own risk.
#
# Update Note
# ===========
# Please use this repository instead of ppa:fkrull/deadsnakes.
#
# Reporting Issues
# ================
# Issues can be reported in the master issue tracker at:
# https://github.com/deadsnakes/issues/issues
#
# Supported Ubuntu and Python Versions
# ====================================
# Python 3.6 - Ubuntu 14.04, Ubuntu 16.04
#
# For Ubuntu up to 18.04, there's also packages for old Python versions from 2.3 to 3.4.
#
# The packages may also work on other versions of Ubuntu or Debian, but that is not tested or supported.
#
# Third-Party Python Modules
# ==========================
# Python modules in the official Ubuntu repositories are packaged to work with the Python interpreters from the official repositories. Accordingly, they generally won't work with the Python interpreters from this PPA. As an exception, pure-Python modules for Python 3 will work, but any compiled extension modules won't.
#
# To install 3rd-party Python modules, you should use the common Python packaging tools.  For an introduction into the Python packaging ecosystem and its tools, refer to the Python Packaging User Guide:
# https://packaging.python.org/installing/
#
# Sources
# =======
# The package sources are available at:
# https://github.com/deadsnakes/
#  More info: https://launchpad.net/~deadsnakes/+archive/ubuntu/ppa
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  Release
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Get:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [83.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [27.1 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [278 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [753 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [130 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [593 kB]
# Fetched 2,044 kB in 3s (803 kB/s)
# Reading package lists... Done
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  Release
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.5-minimal libpython3.5-stdlib python3.5-minimal
# Suggested packages:
#   python3.5-venv python3.5-doc binfmt-support
# The following NEW packages will be installed:
#   libpython3.5-minimal libpython3.5-stdlib python3.5 python3.5-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 11 not upgraded.
# Need to get 4,133 kB of archives.
# After this operation, 22.7 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.5-minimal amd64 3.5.6-1+bionic1 [542 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.5-minimal amd64 3.5.6-1+bionic1 [1,274 kB]
# Get:3 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.5-stdlib amd64 3.5.6-1+bionic1 [2,106 kB]
# Get:4 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.5 amd64 3.5.6-1+bionic1 [210 kB]
# Fetched 4,133 kB in 9s (468 kB/s)
# Selecting previously unselected package libpython3.5-minimal:amd64.
# (Reading database ... 110377 files and directories currently installed.)
# Preparing to unpack .../libpython3.5-minimal_3.5.6-1+bionic1_amd64.deb ...
# Unpacking libpython3.5-minimal:amd64 (3.5.6-1+bionic1) ...
# Selecting previously unselected package python3.5-minimal.
# Preparing to unpack .../python3.5-minimal_3.5.6-1+bionic1_amd64.deb ...
# Unpacking python3.5-minimal (3.5.6-1+bionic1) ...
# Selecting previously unselected package libpython3.5-stdlib:amd64.
# Preparing to unpack .../libpython3.5-stdlib_3.5.6-1+bionic1_amd64.deb ...
# Unpacking libpython3.5-stdlib:amd64 (3.5.6-1+bionic1) ...
# Selecting previously unselected package python3.5.
# Preparing to unpack .../python3.5_3.5.6-1+bionic1_amd64.deb ...
# Unpacking python3.5 (3.5.6-1+bionic1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up libpython3.5-minimal:amd64 (3.5.6-1+bionic1) ...
# Setting up libpython3.5-stdlib:amd64 (3.5.6-1+bionic1) ...
# Setting up python3.5-minimal (3.5.6-1+bionic1) ...
# Setting up python3.5 (3.5.6-1+bionic1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.5 libpython3.5-dev
# The following NEW packages will be installed:
#   libpython3.5 libpython3.5-dev python3.5-dev
# 0 upgraded, 3 newly installed, 0 to remove and 11 not upgraded.
# Need to get 49.5 MB of archives.
# After this operation, 68.2 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.5 amd64 3.5.6-1+bionic1 [1,237 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.5-dev amd64 3.5.6-1+bionic1 [47.8 MB]
# Get:3 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.5-dev amd64 3.5.6-1+bionic1 [413 kB]
# Fetched 49.5 MB in 2min 59s (277 kB/s)
# Selecting previously unselected package libpython3.5:amd64.
# (Reading database ... 111213 files and directories currently installed.)
# Preparing to unpack .../libpython3.5_3.5.6-1+bionic1_amd64.deb ...
# Unpacking libpython3.5:amd64 (3.5.6-1+bionic1) ...
# Selecting previously unselected package libpython3.5-dev:amd64.
# Preparing to unpack .../libpython3.5-dev_3.5.6-1+bionic1_amd64.deb ...
# Unpacking libpython3.5-dev:amd64 (3.5.6-1+bionic1) ...
# Selecting previously unselected package python3.5-dev.
# Preparing to unpack .../python3.5-dev_3.5.6-1+bionic1_amd64.deb ...
# Unpacking python3.5-dev (3.5.6-1+bionic1) ...
# Setting up libpython3.5:amd64 (3.5.6-1+bionic1) ...
# Setting up libpython3.5-dev:amd64 (3.5.6-1+bionic1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up python3.5-dev (3.5.6-1+bionic1) ...
# --2018-12-11 19:41:06--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1661676 (1.6M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   1.58M  --.-KB/s    in 0.05s
#
# 2018-12-11 19:41:06 (30.6 MB/s) - ‘get-pip.py’ saved [1661676/1661676]
#
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/c2/d7/90f34cb0d83a6c5631cf71dfe64cc1054598c843a92b400e55675cc2ac37/pip-18.1-py2.py3-none-any.whl (1.3MB)
#     100% |████████████████████████████████| 1.3MB 15.2MB/s
# Collecting setuptools
#   Downloading https://files.pythonhosted.org/packages/e7/16/da8cb8046149d50940c6110310983abb359bbb8cbc3539e6bef95c29428a/setuptools-40.6.2-py2.py3-none-any.whl (573kB)
#     100% |████████████████████████████████| 573kB 21.5MB/s
# Collecting wheel
#   Downloading https://files.pythonhosted.org/packages/ff/47/1dfa4795e24fd6f93d5d58602dd716c3f101cfd5a77cd9acbe519b44a0a9/wheel-0.32.3-py2.py3-none-any.whl
# Installing collected packages: pip, setuptools, wheel
# Successfully installed pip-18.1 setuptools-40.6.2 wheel-0.32.3
# Collecting Pillow
#   Downloading https://files.pythonhosted.org/packages/bc/cc/b6e47b0075ca4267855d77850af7ea4194d2fc591664f1d70e5151b50637/Pillow-5.3.0-cp35-cp35m-manylinux1_x86_64.whl (2.0MB)
#     100% |████████████████████████████████| 2.0MB 11.3MB/s
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0
# Collecting keras==2.1.1
#   Downloading https://files.pythonhosted.org/packages/e1/49/decea3cbcfc08bd6b2105c5793d958ea159d07f2b43e45a00afe2b35633d/Keras-2.1.1-py2.py3-none-any.whl (302kB)
#     100% |████████████████████████████████| 307kB 11.8MB/s
# Collecting six>=1.9.0 (from keras==2.1.1)
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting numpy>=1.9.1 (from keras==2.1.1)
#   Downloading https://files.pythonhosted.org/packages/86/04/bd774106ae0ae1ada68c67efe89f1a16b2aa373cc2db15d974002a9f136d/numpy-1.15.4-cp35-cp35m-manylinux1_x86_64.whl (13.8MB)
#     100% |████████████████████████████████| 13.8MB 1.9MB/s
# Collecting scipy>=0.14 (from keras==2.1.1)
#   Downloading https://files.pythonhosted.org/packages/cd/32/5196b64476bd41d596a8aba43506e2403e019c90e1a3dfc21d51b83db5a6/scipy-1.1.0-cp35-cp35m-manylinux1_x86_64.whl (33.1MB)
#     100% |████████████████████████████████| 33.1MB 1.1MB/s
# Collecting pyyaml (from keras==2.1.1)
#   Downloading https://files.pythonhosted.org/packages/9e/a3/1d13970c3f36777c583f136c136f804d70f500168edc1edea6daa7200769/PyYAML-3.13.tar.gz (270kB)
#     100% |████████████████████████████████| 276kB 22.7MB/s
# Building wheels for collected packages: pyyaml
# done
#   Stored in directory: /root/.cache/pip/wheels/ad/da/0c/74eb680767247273e2cf2723482cb9c924fe70af57c334513f
# Successfully built pyyaml
# Installing collected packages: six, numpy, scipy, pyyaml, keras
# Successfully installed keras-2.1.1 numpy-1.15.4 pyyaml-3.13 scipy-1.1.0 six-1.12.0
# Collecting lz4
#   Downloading https://files.pythonhosted.org/packages/f1/4f/878f1827042c5b6828bc23d160f31e242ec820810b8bd04b30b631029952/lz4-2.1.2.tar.gz (128kB)
#     100% |████████████████████████████████| 133kB 6.1MB/s
# Building wheels for collected packages: lz4
# done
#   Stored in directory: /root/.cache/pip/wheels/9a/bf/d1/b771620d908af63302309490d1892224364bb541f8e84af67d
# Successfully built lz4
# Installing collected packages: lz4
# Successfully installed lz4-2.1.2
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/82/a8/bcb4beecf2389898d0ff415bf30e871c69977e2f417a3fc223b15b8c5a65/opencv_python-3.4.4.19-cp35-cp35m-manylinux1_x86_64.whl (25.4MB)
#     100% |████████████████████████████████| 25.4MB 1.8MB/s
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.5/dist-packages (from opencv-python) (1.15.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-3.4.4.19
# Collecting h5py
#   Downloading https://files.pythonhosted.org/packages/d9/0a/f0dd6d533d6b5bd4c1ca186af2792186885a90b84df41f3e6867466761fc/h5py-2.8.0-cp35-cp35m-manylinux1_x86_64.whl (2.8MB)
#     100% |████████████████████████████████| 2.8MB 11.0MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.5/dist-packages (from h5py) (1.15.4)
# Requirement already satisfied: six in /usr/local/lib/python3.5/dist-packages (from h5py) (1.12.0)
# Installing collected packages: h5py
# Successfully installed h5py-2.8.0
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/b1/ad/48395de38c1e07bab85fc3bbec045e11ae49c02a4db0100463dd96031947/tensorflow-1.12.0-cp35-cp35m-manylinux1_x86_64.whl (83.1MB)
#     100% |████████████████████████████████| 83.1MB 360kB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.5/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.5/dist-packages (from tensorflow) (1.15.4)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.5/dist-packages (from tensorflow) (0.32.3)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting grpcio>=1.8.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/c9/5f/3bb67a84b671a294dfe6564680b86790dda21fe0549f487dfed795c637ef/grpcio-1.17.0-cp35-cp35m-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 8.7MB/s
# Collecting astor>=0.6.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/35/6b/11530768cac581a12952a2aad00e1526b89d242d0b9f59534ef6e6a1752f/astor-0.7.1-py2.py3-none-any.whl
# Collecting keras-applications>=1.0.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/3f/c4/2ff40221029f7098d58f8d7fb99b97e8100f3293f9856f0fb5834bef100b/Keras_Applications-1.0.6-py2.py3-none-any.whl (44kB)
#     100% |████████████████████████████████| 51kB 20.5MB/s
# Collecting protobuf>=3.6.1 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/bf/d4/db7296a1407cad69f043537ba1e05afab3646451a066ead7a314d8714388/protobuf-3.6.1-cp35-cp35m-manylinux1_x86_64.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 13.2MB/s
# Collecting tensorboard<1.13.0,>=1.12.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/e0/d0/65fe48383146199f16dbd5999ef226b87bce63ad5cd73c840cf722637969/tensorboard-1.12.0-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.1MB 10.1MB/s
# Collecting gast>=0.2.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/5c/78/ff794fcae2ce8aa6323e789d1f8b3b7765f601e7702726f430e814822b96/gast-0.2.0.tar.gz
# Collecting keras-preprocessing>=1.0.5 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/fc/94/74e0fa783d3fc07e41715973435dd051ca89c550881b3454233c39c73e69/Keras_Preprocessing-1.0.5-py2.py3-none-any.whl
# Collecting absl-py>=0.1.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/0c/63/f505d2d4c21db849cf80bad517f0065a30be6b006b0a5637f1b95584a305/absl-py-0.6.1.tar.gz (94kB)
#     100% |████████████████████████████████| 102kB 27.0MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.5/dist-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.5/dist-packages (from protobuf>=3.6.1->tensorflow) (40.6.2)
# Collecting werkzeug>=0.11.10 (from tensorboard<1.13.0,>=1.12.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/20/c4/12e3e56473e52375aa29c4764e70d1b8f3efa6682bef8d0aae04fe335243/Werkzeug-0.14.1-py2.py3-none-any.whl (322kB)
#     100% |████████████████████████████████| 327kB 12.1MB/s
# Collecting markdown>=2.6.8 (from tensorboard<1.13.0,>=1.12.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/7a/6b/5600647404ba15545ec37d2f7f58844d690baf2f81f3a60b862e48f29287/Markdown-3.0.1-py2.py3-none-any.whl (89kB)
#     100% |████████████████████████████████| 92kB 26.8MB/s
# Building wheels for collected packages: termcolor, gast, absl-py
# done
#   Stored in directory: /root/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
# done
#   Stored in directory: /root/.cache/pip/wheels/9a/1f/0e/3cde98113222b853e98fc0a8e9924480a3e25f1b4008cedb4f
# done
#   Stored in directory: /root/.cache/pip/wheels/18/ea/5e/e36e1b8739e78cd2eba0a08fdc602c2b16a4b263912af8cb64
# Successfully built termcolor gast absl-py
# Installing collected packages: termcolor, grpcio, astor, keras-applications, protobuf, werkzeug, markdown, tensorboard, gast, keras-preprocessing, absl-py, tensorflow
# Successfully installed absl-py-0.6.1 astor-0.7.1 gast-0.2.0 grpcio-1.17.0 keras-applications-1.0.6 keras-preprocessing-1.0.5 markdown-3.0.1 protobuf-3.6.1 tensorboard-1.12.0 tensorflow-1.12.0 termcolor-1.1.0 werkzeug-0.14.1
# Requirement already satisfied: lz4 in /usr/local/lib/python3.5/dist-packages (2.1.2)
# Collecting numba
#   Downloading https://files.pythonhosted.org/packages/a5/b9/b532d8889c8a78045c5a6c7887a999de4dfb72db4f74fd6d6e7efb4b1f07/numba-0.41.0-cp35-cp35m-manylinux1_x86_64.whl (3.2MB)
#     100% |████████████████████████████████| 3.2MB 1.3MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.5/dist-packages (from numba) (1.15.4)
# Collecting llvmlite>=0.26.0dev0 (from numba)
#   Downloading https://files.pythonhosted.org/packages/f9/ad/17deffd4c88b1c50d57b97547e33ef652f27a561347b8441f01901a3014e/llvmlite-0.26.0-cp35-cp35m-manylinux1_x86_64.whl (16.1MB)
#     100% |████████████████████████████████| 16.1MB 2.5MB/s
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.26.0 numba-0.41.0
# Cloning into 'image2mass'...
# remote: Enumerating objects: 490, done.
# remote: Total 490 (delta 0), reused 0 (delta 0), pack-reused 490
# Receiving objects: 100% (490/490), 355.21 MiB | 33.34 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# Checking out files: 100% (436/436), done.
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython']
# ['', '/env/python', '/usr/lib/python35.zip', '/usr/lib/python3.5', '/usr/lib/python3.5/lib-dynload', '/usr/local/lib/python3.5/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.5/dist-packages/IPython/extensions', '/root/.ipython']
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"
# Downloaded content "None"

# %% [markdown]
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython']

# %% [markdown]
# ##Run the code

# %%
# !python3.5 predict_mass.py test_set_images/airplane_clock_1.jpg 6.25 1.25 2.125 2>/dev/null
# Out:
# models/shape_aware.h5
# Got: filename= test_set_images/airplane_clock_1.jpg dimensions= ( 6.25 inches by 1.25 inches by 2.125 inches.)
# test_set_images/airplane_clock_1.jpg probably weighs about 0.33056593 pounds.
